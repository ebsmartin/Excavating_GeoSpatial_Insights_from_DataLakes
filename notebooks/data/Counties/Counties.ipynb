# %% [markdown]
# Source: https://www.sciencebase.gov/catalog/item/52c79543e4b060b9ebca5bf4
#
#
# Download:
# 1. tl_2012_us_county.shp
# 2. tl_2012_us_county.shx

# %%
import geopandas

# %%
shape_file = geopandas.read_file('./tl_2012_us_county.shp')

# %%
print(shape_file.crs)
shape_file = shape_file.to_crs("EPSG:4326")
# Out:
# PROJCS["Popular Visualisation CRS / Mercator",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],TOWGS84[0,0,0,0,0,0,0],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]],PROJECTION["Mercator_1SP"],PARAMETER["central_meridian",0],PARAMETER["scale_factor",1],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],EXTENSION["PROJ4","+proj=merc +a=6378137 +b=6378137 +lat_ts=0 +lon_0=0 +x_0=0 +y_0=0 +k=1 +units=m +nadgrids=@null +wktext +no_defs"]]

# %%
print(shape_file.crs)
# Out:
# EPSG:4326

# %%
shape_file.head()
# Out:
#    OBJECTID STATEFP COUNTYFP  COUNTYNS  GEOID      NAME         NAMELSAD LSAD  \
# 0         1      15      001  00365280  15001    Hawaii    Hawaii County   06
# 1         2      05      027  00063761  05027  Columbia  Columbia County   06
# 2         3      38      011  01035619  38011    Bowman    Bowman County   06
# 3         4      36      031  00974114  36031     Essex     Essex County   06
# 4         5      35      007  00929117  35007    Colfax    Colfax County   06
#
#   CLASSFP  MTFCC  ...         ALAND        AWATER     INTPTLAT      INTPTLON  \
# 0      H1  G4020  ...  1.043360e+10  2.739478e+09  +19.5977643  -155.5024434
# 1      H1  G4020  ...  1.984071e+09  1.809509e+06  +33.2230377  -093.2328433
# 2      H1  G4020  ...  3.009064e+09  1.358798e+07  +46.1101438  -103.5059433
# 3      H1  G4020  ...  4.647119e+09  3.159623e+08  +44.1089711  -073.7775726
# 4      H1  G4020  ...  9.733551e+09  2.631038e+07  +36.6129625  -104.6401256
#
# ...

# %%
shape_file.count()
# Out:
# OBJECTID      3234
# STATEFP       3234
# COUNTYFP      3234
# COUNTYNS      3234
# GEOID         3234
# NAME          3234
# NAMELSAD      3234
# LSAD          3234
# CLASSFP       3234
# MTFCC         3234
# CSAFP          904
# CBSAFP        1862
# METDIVFP       108
# FUNCSTAT      3234
# ALAND         3234
# AWATER        3234
# INTPTLAT      3234
# INTPTLON      3234
# STATNAME      3234
# REGION        3234
# STUSPS        3234
# Shape_Leng    3234
# Shape_Area    3234
# geometry      3234
# dtype: int64

# %%
# Loop through each unique state in the DataFrame
for state in shape_file['STATNAME'].unique():
    # Filter the DataFrame for the current state
    condition = shape_file['STATNAME'] == state
    filtered_gdf = shape_file[condition]

    filename = f'{state.replace(" ", "")}Counties.geojson'
    filtered_gdf.to_file(filename, driver='GeoJSON')
    print(f'Exported {filename}')
# Out:
# Exported HawaiiCounties.geojson
# Exported ArkansasCounties.geojson
# Exported NorthDakotaCounties.geojson
# Exported NewYorkCounties.geojson
# Exported NewMexicoCounties.geojson
# Exported MontanaCounties.geojson
# Exported SouthDakotaCounties.geojson
# Exported OregonCounties.geojson
# Exported UtahCounties.geojson
# Exported WashingtonCounties.geojson
# Exported IdahoCounties.geojson
# Exported AmericanSamoaCounties.geojson
# Exported CommonwealthoftheNorthernMarianaIslandsCounties.geojson
# Exported PuertoRicoCounties.geojson
# Exported NewJerseyCounties.geojson
# Exported OklahomaCounties.geojson
# Exported RhodeIslandCounties.geojson
# Exported LouisianaCounties.geojson
# Exported ConnecticutCounties.geojson
# Exported UnitedStatesVirginIslandsCounties.geojson
# Exported WestVirginiaCounties.geojson
# Exported OhioCounties.geojson
# Exported KentuckyCounties.geojson
# Exported GeorgiaCounties.geojson
# Exported MississippiCounties.geojson
# ...
