# %%
# %pip install geopandas matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

# Replace 'your_file.geojson' with the path to your GeoJSON file
geojson_path = '../rawDatasets/CountryTerritories/CountryTerritories.geojson'
geo_data = gpd.read_file(geojson_path)

# %%
print(geo_data.crs)
# Out:
# EPSG:4326

# %%
print(geo_data.head())
print(geo_data.columns)
print(geo_data.count)
# Out:
#                                         geo_point_2d  iso3        status  \
# 0  {'lon': 33.74379108021756, 'lat': 21.892740179...  None   Adm. by EGY
# 1  {'lon': 8.234429172288662, 'lat': 46.802569376...   CHE  Member State
# 2  {'lon': -2.1286489627456704, 'lat': 49.2191154...  None  UK Territory
# 3  {'lon': 14.14019348879525, 'lat': 47.592902606...   AUT  Member State
# 4  {'lon': -7.962187190752776, 'lat': 39.69190982...   PRT  Member State
#
#   color_code             name continent           region  \
# 0        EGY  Ma'tan al-Sarra    Africa  Northern Africa
# 1        CHE      Switzerland    Europe   Western Europe
# 2        GBR           Jersey    Europe  Northern Europe
# 3        AUT          Austria    Europe   Western Europe
# 4        PRT         Portugal    Europe  Southern Europe
#
#   iso_3166_1_alpha_2_codes     french_short  \
# 0                     None  Ma'tan al-Sarra
# 1                       CH           Suisse
# ...

# %%
import matplotlib.pyplot as plt

geo_data.plot()
plt.show()

# %%
geo_data.to_file('CountryTerritories.geojson', driver='GeoJSON')
